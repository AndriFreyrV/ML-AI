# %% [markdown]
# ## REI 603M - Assignment 2
# ### Andri Freyr Viðarsson
#
# In this notebook data on the top divisions of icelandic football is collected from the icelandic football association, https://www.ksi.is. The scraping is performed using the library Gazpacho and the data is exported as csv files. The icelandic football association has kept data on the men's league since the 1910s and data on the women's league since it's establishment in the 1970s. More extensive data is available on seasons that took place after the mid 1980s.
#
# Each row in the exported datasets corresponds to a single team for a given year. The datasets have 18 columns, the columns are:
#
# *team_name*: Team name<br />
# *year*: Year<br />
# *place*: Spot in the league table at end of season<br />
# *played_games*: Number of games that the team played in the season<br />
# *n_wins*: Number of games won<br />
# *n_ties*: Number of ties<br />
# *n_losses*: Number of losses<br />
# *goals_scored*: Number of goals scored<br />
# *goals_against*: Number of goals conceded<br />
# *goal_difference*: goals_scored - goals_agianst<br />
# *points*: Number of points<br />
# *points_3point_scale*: points on 3 point scale, (3 points for win, 1 for draw), first used in 1984<br />
# *teams_in_league*: Number of participating teams<br />
# *url*: URL for team info site<br />
# *n_yellow_cards*: Number of yellow cards<br />
# *n_red_cards*: Number of red cards<br />
# *avg_weighted_age*: Average age of players in the team, weighted by played minutes<br />
# *avg_home_attendance*: Average attendance at home games

# %%
from gazpacho import get, Soup
import pandas as pd
import time
import re

# %%
base_url = 'https://www.ksi.is'

# %% [markdown]
# Here we get the url to the league table for the latest season, pass parameter 'm' for mens league, 'w' for women's league. The scraping starts from this url.

# %%
def get_start_url(gender):
    # params: gender: m or f, m for male league, f for female
    # returns: url for most recent tournament for the gender
    index = 1 if gender == 'm' else 2
    html = get(base_url)
    soup = Soup(html)
    nav = soup.find('nav', {'class': 'main-nav'})
    bla = nav.find('div', {'class':'col-md-3'})[1]
    ul = bla.find('ul')[index] # 1 for male, 2 for female
    li = ul.find('li')[0]
    a = li.find('a').attrs
    if 'https:' in a['href']: # some problem with relative paths
        return a['href']
    start_url = base_url + a['href']
    return start_url
    
get_start_url('m')
# Out:
# 'https://www.ksi.is/mot/stakt-mot/?motnumer=43801'

# %% [markdown]
# From the latest league table we gather urls for all previous years

# %%
def get_tournament_urls(start_url):
    # get url for league table for all previous years 
    html = get(start_url)
    soup = Soup(html)
    dropdown = soup.find('ul', {'class':'dropdown-menu'})[1].find('li')[1:]
    urls = []
    for i in dropdown:
        href = i.find('a').attrs['href']
        year = i.find('a').text.lower()
        if 'riðill' not in year and 'úrslit' not in year and 'auka' not in year:
            urls.append({'year':int(year[:4]), 'url': base_url+href})
    return urls
get_tournament_urls(get_start_url('m'))
# Out:
# [{'year': 2022,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=43525'},
#  {'year': 2022,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=44701'},
#  {'year': 2021,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=42373'},
#  {'year': 2020,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=40928'},
#  {'year': 2019,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=38296'},
#  {'year': 2018,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=37403'},
#  {'year': 2017,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=36622'},
#  {'year': 2016,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=35586'},
#  {'year': 2015,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=33503'},
#  {'year': 2014,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=32265'},
#  {'year': 2013,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=29465'},
#  {'year': 2012,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=26463'},
#  {'year': 2011,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=23425'},
#  {'year': 2010,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=19847'},
#  {'year': 2009,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=17548'},
#  {'year': 2008,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=16788'},
#  {'year': 2007,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=14843'},
#  {'year': 2006,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=12486'},
#  {'year': 2005,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=8585'},
#  {'year': 2004,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=6366'},
#  {'year': 2003,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=3983'},
#  {'year': 2002,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=1483'},
#  {'year': 2001,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=243'},
#  {'year': 2000,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10547'},
#  {'year': 1999,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10546'},
#  {'year': 1998,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10545'},
#  {'year': 1997,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10544'},
#  {'year': 1996,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10543'},
#  {'year': 1995,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10525'},
#  {'year': 1994,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10524'},
#  {'year': 1993,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10523'},
#  {'year': 1992,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10506'},
#  {'year': 1991,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10505'},
#  {'year': 1990,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10504'},
#  {'year': 1989,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10503'},
#  {'year': 1988,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10487'},
#  {'year': 1987,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10486'},
#  {'year': 1986,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10485'},
#  {'year': 1985,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10484'},
#  {'year': 1984,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10483'},
#  {'year': 1983,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10463'},
#  {'year': 1982,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10443'},
#  {'year': 1981,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10425'},
#  {'year': 1980,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10423'},
#  {'year': 1979,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10403'},
#  {'year': 1978,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10385'},
#  {'year': 1977,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10384'},
#  {'year': 1976,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10383'},
#  {'year': 1975,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10365'},
#  {'year': 1974,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10364'},
#  {'year': 1973,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10363'},
#  {'year': 1972,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10347'},
#  {'year': 1971,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10346'},
#  {'year': 1970,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10345'},
#  {'year': 1969,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10344'},
#  {'year': 1968,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10343'},
#  {'year': 1967,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10326'},
#  {'year': 1966,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10325'},
#  {'year': 1965,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10324'},
#  {'year': 1964,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10323'},
#  {'year': 1963,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10303'},
#  {'year': 1962,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10288'},
#  {'year': 1961,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10287'},
#  {'year': 1960,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10275'},
#  {'year': 1959,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10274'},
#  {'year': 1958,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10273'},
#  {'year': 1957,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10272'},
#  {'year': 1956,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10271'},
#  {'year': 1955,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10270'},
#  {'year': 1954,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10269'},
#  {'year': 1952,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10265'},
#  {'year': 1951,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10264'},
#  {'year': 1950,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10263'},
#  {'year': 1949,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10257'},
#  {'year': 1948,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10784'},
#  {'year': 1947,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10256'},
#  {'year': 1946,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10255'},
#  {'year': 1945,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10254'},
#  {'year': 1944,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10783'},
#  {'year': 1943,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10253'},
#  {'year': 1942,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10251'},
#  {'year': 1941,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10250'},
#  {'year': 1940,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10249'},
#  {'year': 1939,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10248'},
#  {'year': 1938,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10247'},
#  {'year': 1937,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10246'},
#  {'year': 1936,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10245'},
#  {'year': 1935,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10244'},
#  {'year': 1934,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10243'},
#  {'year': 1933,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10241'},
#  {'year': 1932,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10240'},
#  {'year': 1931,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10239'},
#  {'year': 1930,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10238'},
#  {'year': 1929,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10286'},
#  {'year': 1928,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10237'},
#  {'year': 1927,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10236'},
#  {'year': 1926,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10234'},
#  {'year': 1925,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10233'},
#  {'year': 1924,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10232'},
#  {'year': 1923,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10231'},
#  {'year': 1922,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10230'},
#  {'year': 1921,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10229'},
#  {'year': 1920,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10228'},
#  {'year': 1919,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10227'},
#  {'year': 1918,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10226'},
#  {'year': 1917,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10225'},
#  {'year': 1916,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=10223'},
#  {'year': 1915,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=9704'},
#  {'year': 1914,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=17783'},
#  {'year': 1913,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=17784'},
#  {'year': 1912,
#   'url': 'https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=9683'}]

# %% [markdown]
# Given a team_url and team_name we get average home attendance for the team by going through each match report linked to the team's home games and collecting the attendance numbers.

# %%
def get_avg_attendance(team_url, team_name):
    attendance_ls = []
    html = get(team_url)
    soup = Soup(html)
    games_url = base_url + soup.find('div', {'class': 'btn-group pull-right'}).find('a')[2].attrs['href']
    
    html_games = get(games_url)
    soup_games = Soup(html_games)
    results = soup_games.find('div', {'class': 'results-area'}).find('table', {'class': 'games-list'})
    for r in results:
        home_team = r.find('ul', {'class': 'list type2'}).find('li')[0].find('span').text
        if home_team == team_name:
            match_report = r.find('ul', {'class':'img-list'}).find('li')[-1].find('a').attrs['href']
            game_url = base_url + match_report
            n_fans = get_attendance(game_url)
            if n_fans:
                attendance_ls.append(n_fans)
    if len(attendance_ls) > 0:
        return sum(attendance_ls)/len(attendance_ls)
    return None
        
def get_attendance(game_url):
    html = get(game_url)
    soup = Soup(html)
    info = soup.find('div', {'class': 'report-head'}).find('p').find('span')
    try:
        att_str = re.findall(r'\(.*?\)', str(info))[0]
        attendance = int(att_str[1:-1].split(':')[1])
        return attendance
    except:
        return None
    

get_avg_attendance('https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=40928&lid=101', 'Valur')
# Out:
# 680.0

# %% [markdown]
# Here we collect data from the league table and additional data from team pages.

# %%
def get_league_table(url, year):
    html = get(url)
    soup = Soup(html)
    table = soup.find('table', {'class':'situation-list'})
    body = table.find('tbody')
    rows = body.find('tr')
    n_teams = len(rows)
    teams_info = []
    for r in rows:
        info = r.find('td')[0]
        team_name = info.find('span', {'class':'name'}).text
        team_stats = r.find('td')[1:8]
        goals_scored = int(team_stats[4].text.split(':')[0])
        goals_against = int(team_stats[4].text.split(':')[1])
        goal_difference = goals_scored - goals_against
        
        team_url = base_url + info.find('a').attrs['href']
        try:
            n_yellows, n_reds, avg_weighted_age = get_team_info(team_url, year)
            avg_home_attendance = get_avg_attendance(team_url, team_name)
        except:
            n_yellows, n_reds, avg_weighted_age = None, None, None
            avg_home_attendance = None
           
        teams_info.append({
            'team_name': team_name,
            'year':year,
            'place': int(info.find('span', {'class':'num'}).text),
            'played_games': int(team_stats[0].text),
            'n_wins': int(team_stats[1].text),
            'n_ties': int(team_stats[2].text),
            'n_losses': int(team_stats[3].text),
            'goals_scored': goals_scored,
            'goals_against': goals_against,
            'goal_difference': goal_difference,
            'points': int(team_stats[6].text),
            'points_3point_scale': 3*int(team_stats[1].text)+int(team_stats[2].text),
            'teams_in_league':n_teams,
            'url':team_url,
            'n_yellow_cards':n_yellows,
            'n_red_cards': n_reds,
            'avg_weighted_age': avg_weighted_age,
            'avg_home_attendance': avg_home_attendance
        })
    return teams_info



def get_team_info(url, year):
    # params: url: url for team page
    # returns: total number of reds and yellows and weighted avg player age
    html = get(url)
    soup = Soup(html)
    n_yellows = 0
    n_red_cards = 0
    weighted_ages = []
    sum_minutes = 0
    players_list = soup.find('ul', {'class': 'profile-grid players'}).find('li')
    for player in players_list:
        birth_year = int(player.find('h3', {'class': 'birth-year'}).text)
        age = year - birth_year
        perc_minutes = float(player.find('div',{'class': 'chart-item'})[1].attrs['data-value'])
        sum_minutes += perc_minutes
        weighted_ages.append(perc_minutes*age)
        
        bookings_info = player.find('ul', {'class': 'list'}).find('li')[1:]
        n_yellows += int(bookings_info[0].text)
        n_red_cards += int(bookings_info[1].text)
    
    avg_weighted_age = sum(weighted_ages)/sum_minutes # sum_minutes should be 11 and is for most years
    # however something wrong with 2020 because of short covid season
    
    return n_yellows, n_red_cards, avg_weighted_age
        
                
get_league_table('https://www.ksi.is/mot/stakt-mot/$TournamentDetails/Table/?motnumer=12486', 2006)
# Out:
# [{'team_name': 'FH',
#   'year': 2006,
#   'place': 1,
#   'played_games': 18,
#   'n_wins': 10,
#   'n_ties': 6,
#   'n_losses': 2,
#   'goals_scored': 31,
#   'goals_against': 14,
#   'goal_difference': 17,
#   'points': 36,
#   'points_3point_scale': 36,
#   'teams_in_league': 10,
#   'url': 'https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=12486&lid=220',
#   'n_yellow_cards': 22,
#   'n_red_cards': 3,
#   'avg_weighted_age': 27.27822671156005,
#   'avg_home_attendance': 1948.4444444444443},
#  {'team_name': 'KR',
#   'year': 2006,
#   'place': 2,
#   'played_games': 18,
#   'n_wins': 9,
#   'n_ties': 3,
#   'n_losses': 6,
#   'goals_scored': 23,
#   'goals_against': 27,
#   'goal_difference': -4,
#   'points': 30,
#   'points_3point_scale': 30,
#   'teams_in_league': 10,
#   'url': 'https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=12486&lid=107',
#   'n_yellow_cards': 29,
#   'n_red_cards': 6,
#   'avg_weighted_age': 27.076167076167067,
#   'avg_home_attendance': 1459.7777777777778},
#  {'team_name': 'Valur',
#   'year': 2006,
#   'place': 3,
#   'played_games': 18,
#   'n_wins': 7,
#   'n_ties': 8,
#   'n_losses': 3,
#   'goals_scored': 27,
#   'goals_against': 18,
#   'goal_difference': 9,
#   'points': 29,
#   'points_3point_scale': 29,
#   'teams_in_league': 10,
#   'url': 'https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=12486&lid=101',
#   'n_yellow_cards': 34,
#   'n_red_cards': 0,
#   'avg_weighted_age': 26.73031825795645,
#   'avg_home_attendance': 858.2222222222222},
#  {'team_name': 'Keflavík',
#   'year': 2006,
#   'place': 4,
#   'played_games': 18,
#   'n_wins': 6,
#   'n_ties': 6,
#   'n_losses': 6,
#   'goals_scored': 30,
#   'goals_against': 20,
#   'goal_difference': 10,
#   'points': 24,
#   'points_3point_scale': 24,
#   'teams_in_league': 10,
#   'url': 'https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=12486&lid=230',
#   'n_yellow_cards': 32,
#   'n_red_cards': 3,
#   'avg_weighted_age': 23.604124635731903,
#   'avg_home_attendance': 1148.4444444444443},
#  {'team_name': 'Breiðablik',
#   'year': 2006,
#   'place': 5,
#   'played_games': 18,
#   'n_wins': 6,
#   'n_ties': 5,
#   'n_losses': 7,
#   'goals_scored': 27,
#   'goals_against': 33,
#   'goal_difference': -6,
#   'points': 23,
#   'points_3point_scale': 23,
#   'teams_in_league': 10,
#   'url': 'https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=12486&lid=200',
#   'n_yellow_cards': 40,
#   'n_red_cards': 1,
#   'avg_weighted_age': 26.355389959659345,
#   'avg_home_attendance': 949.1111111111111},
#  {'team_name': 'ÍA',
#   'year': 2006,
#   'place': 6,
#   'played_games': 18,
#   'n_wins': 6,
#   'n_ties': 4,
#   'n_losses': 8,
#   'goals_scored': 27,
#   'goals_against': 30,
#   'goal_difference': -3,
#   'points': 22,
#   'points_3point_scale': 22,
#   'teams_in_league': 10,
#   'url': 'https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=12486&lid=300',
#   'n_yellow_cards': 35,
#   'n_red_cards': 1,
#   'avg_weighted_age': 26.85078563411897,
#   'avg_home_attendance': 1059.7777777777778},
#  {'team_name': 'Víkingur R.',
#   'year': 2006,
#   'place': 7,
#   'played_games': 18,
#   'n_wins': 5,
#   'n_ties': 6,
#   'n_losses': 7,
#   'goals_scored': 21,
#   'goals_against': 18,
#   'goal_difference': 3,
#   'points': 21,
#   'points_3point_scale': 21,
#   'teams_in_league': 10,
#   'url': 'https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=12486&lid=103',
#   'n_yellow_cards': 32,
#   'n_red_cards': 0,
#   'avg_weighted_age': 24.45117845117845,
#   'avg_home_attendance': 1039.2222222222222},
#  {'team_name': 'Fylkir',
#   'year': 2006,
#   'place': 8,
#   'played_games': 18,
#   'n_wins': 5,
#   'n_ties': 6,
#   'n_losses': 7,
#   'goals_scored': 22,
#   'goals_against': 25,
#   'goal_difference': -3,
#   'points': 21,
#   'points_3point_scale': 21,
#   'teams_in_league': 10,
#   'url': 'https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=12486&lid=110',
#   'n_yellow_cards': 36,
#   'n_red_cards': 0,
#   'avg_weighted_age': 26.268013468013464,
#   'avg_home_attendance': 922.2222222222222},
#  {'team_name': 'Grindavík',
#   'year': 2006,
#   'place': 9,
#   'played_games': 18,
#   'n_wins': 4,
#   'n_ties': 7,
#   'n_losses': 7,
#   'goals_scored': 24,
#   'goals_against': 26,
#   'goal_difference': -2,
#   'points': 19,
#   'points_3point_scale': 19,
#   'teams_in_league': 10,
#   'url': 'https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=12486&lid=240',
#   'n_yellow_cards': 31,
#   'n_red_cards': 6,
#   'avg_weighted_age': 26.54898989898991,
#   'avg_home_attendance': 906.4444444444445},
#  {'team_name': 'ÍBV',
#   'year': 2006,
#   'place': 10,
#   'played_games': 18,
#   'n_wins': 5,
#   'n_ties': 3,
#   'n_losses': 10,
#   'goals_scored': 18,
#   'goals_against': 39,
#   'goal_difference': -21,
#   'points': 18,
#   'points_3point_scale': 18,
#   'teams_in_league': 10,
#   'url': 'https://www.ksi.is/mot/stakt-mot/lid-i-moti/?motnumer=12486&lid=900',
#   'n_yellow_cards': 42,
#   'n_red_cards': 4,
#   'avg_weighted_age': 24.489082723691617,
#   'avg_home_attendance': 599.8888888888889}]

# %% [markdown]
# In the following cells all the previous functions are combined and the final product is returned

# %%
def get_historic_data(gender):
    # params: m for male league, f for female league
    data = []
    years_info = get_tournament_urls(get_start_url(gender))
    for dict_ in years_info:
        try:
            league_table = get_league_table(dict_['url'], dict_['year'])
            data +=league_table
        except:
            print(dict_['year'])
    return data

# %%
start_time = time.time()
df = pd.DataFrame(get_historic_data('m'))
print(f'Elapsed time: {time.time()-start_time}' )
df

# %%
df.loc[df['team_name'] == 'Haukar']
# Out:
#     team_name  year  place  played_games  n_wins  n_ties  n_losses  \
# 130    Haukar  2010     11            22       4       8        10
# 435    Haukar  1979     10            18       1       3        14
#
#      goals_scored  goals_against  goal_difference  points  \
# 130            29             45              -16      20
# 435            12             45              -33       5
#
#      points_3point_scale  teams_in_league  \
# 130                   20               12
# 435                    6               10
#
#                                                    url  n_yellow_cards  \
# 130  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            48.0
# 435  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...             NaN
#
#      n_red_cards  avg_weighted_age  avg_home_attendance
# 130          1.0          26.87337           759.454545
# 435          NaN               NaN                  NaN

# %%
df.loc[df['team_name'] == 'FH']
# Out:
#     team_name  year  place  played_games  n_wins  n_ties  n_losses  \
# 1          FH  2020      2            18      11       3         4
# 14         FH  2019      3            22      11       4         7
# 28         FH  2018      5            22      10       7         5
# 38         FH  2017      3            22       9       8         5
# 48         FH  2016      1            22      12       7         3
# 60         FH  2015      1            22      15       3         4
# 73         FH  2014      2            22      15       6         1
# 85         FH  2013      2            22      14       5         3
# 96         FH  2012      1            22      15       4         3
# 109        FH  2011      2            22      13       5         4
# 121        FH  2010      2            22      13       5         4
# 132        FH  2009      1            22      16       3         3
# 144        FH  2008      1            22      15       2         5
# 157        FH  2007      2            18      11       4         3
# 166        FH  2006      1            18      10       6         2
# 176        FH  2005      1            18      16       0         2
# 186        FH  2004      1            18      10       7         1
# 197        FH  2003      2            18       9       3         6
# 211        FH  2002      6            18       5       7         6
# 218        FH  2001      3            18       9       5         4
# 274        FH  1995      9            18       4       3        11
# 277        FH  1994      2            18      11       3         4
# 287        FH  1993      2            18      12       4         2
# 301        FH  1992      6            18       5       6         7
# 313        FH  1991      8            18       6       4         8
# 321        FH  1990      6            18       7       2         9
# 327        FH  1989      2            18       9       5         4
# 355        FH  1987     10            18       4       4        10
# 363        FH  1986      8            18       5       4         9
# 372        FH  1985      7            18       5       2        11
# 415        FH  1981     10            18       2       3        13
# 423        FH  1980      8            18       5       5         8
# 444        FH  1978      9            18       2       6        10
# 452        FH  1977      7            18       5       6         7
# 463        FH  1976      8            16       2       4        10
# 470        FH  1975      6            14       4       5         5
#
#      goals_scored  goals_against  goal_difference  points  \
# 1              37             23               14      36
# 14             40             36                4      37
# 28             36             28                8      37
# 38             33             25                8      35
# 48             32             17               15      43
# 60             47             26               21      48
# 73             46             17               29      51
# 85             47             22               25      47
# 96             51             23               28      49
# 109            48             31               17      44
# 121            48             31               17      44
# 132            57             21               36      51
# 144            50             25               25      47
# 157            42             26               16      37
# 166            31             14               17      36
# 176            53             11               42      48
# 186            33             16               17      37
# 197            36             24               12      30
# 211            29             30               -1      22
# 218            23             16                7      32
# 274            26             42              -16      15
# 277            26             16               10      36
# 287            39             21               18      40
# 301            25             29               -4      21
# 313            26             32               -6      22
# 321            24             29               -5      23
# 327            27             17               10      32
# 355            22             34              -12      16
# 363            24             36              -12      19
# 372            23             41              -18      17
# 415            20             42              -22       7
# 423            24             34              -10      15
# 444            22             37              -15      10
# 452            26             30               -4      16
# 463            11             31              -20       8
# 470            11             21              -10      13
#
#      points_3point_scale  teams_in_league  \
# 1                     36               12
# 14                    37               12
# 28                    37               12
# 38                    35               12
# 48                    43               12
# 60                    48               12
# 73                    51               12
# 85                    47               12
# 96                    49               12
# 109                   44               12
# 121                   44               12
# 132                   51               12
# 144                   47               12
# 157                   37               10
# 166                   36               10
# 176                   48               10
# 186                   37               10
# 197                   30               10
# 211                   22               10
# 218                   32               10
# 274                   15               10
# 277                   36               10
# 287                   40               10
# 301                   21               10
# 313                   22               10
# 321                   23               10
# 327                   32               10
# 355                   16               10
# 363                   19               10
# 372                   17               10
# 415                    9               10
# 423                   20               10
# 444                   12               10
# 452                   21               10
# 463                   10                9
# 470                   17                8
#
#                                                    url  n_yellow_cards  \
# 1    https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            37.0
# 14   https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            51.0
# 28   https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            48.0
# 38   https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            51.0
# 48   https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            48.0
# 60   https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            52.0
# 73   https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            34.0
# 85   https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            44.0
# 96   https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            43.0
# 109  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            41.0
# 121  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            40.0
# 132  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            46.0
# 144  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            34.0
# 157  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            23.0
# 166  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            22.0
# 176  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            16.0
# 186  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            32.0
# 197  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            29.0
# 211  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            30.0
# 218  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            24.0
# 274  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            40.0
# 277  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            26.0
# 287  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            27.0
# 301  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            17.0
# 313  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            19.0
# 321  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            24.0
# 327  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            17.0
# 355  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            25.0
# 363  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            11.0
# 372  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...            13.0
# 415  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...             NaN
# 423  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...             NaN
# 444  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...             NaN
# 452  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...             NaN
# 463  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...             NaN
# 470  https://www.ksi.is/mot/stakt-mot/lid-i-moti/?m...             NaN
#
#      n_red_cards  avg_weighted_age  avg_home_attendance
# 1            3.0         28.466667           620.600000
# 14           4.0         28.345102          1205.818182
# 28           3.0         28.281836          1069.454545
# 38           1.0         27.511369          1060.090909
# 48           1.0         26.604759          1540.636364
# 60           1.0         26.543360          1924.727273
# 73           4.0         27.177778          1740.727273
# 85           4.0         27.098072          1496.181818
# 96           2.0         28.924197          1595.363636
# 109          5.0         28.656933          1685.727273
# 121          4.0         27.595787          1781.000000
# 132          1.0         27.409072          1532.272727
# 144          2.0         28.629767          1256.000000
# 157          2.0         28.720169          2306.111111
# 166          3.0         27.278227          1948.444444
# 176          3.0         28.176431          1972.666667
# 186          1.0         26.433670          1573.555556
# 197          1.0         25.576992           848.777778
# 211          2.0         25.632021           957.777778
# 218          0.0         25.372110          1204.444444
# 274          4.0         26.317197           460.555556
# 277          4.0         26.731201           618.000000
# 287          1.0         25.338384           777.000000
# 301          1.0         26.504040           455.000000
# 313          0.0         26.868687           771.555556
# 321          0.0         26.419192           383.125000
# 327          0.0         26.474747           743.555556
# 355          3.0         24.787879           433.666667
# 363          0.0         25.005051           473.333333
# 372          0.0         24.977528           591.555556
# 415          NaN               NaN                  NaN
# 423          NaN               NaN                  NaN
# 444          NaN               NaN                  NaN
# 452          NaN               NaN                  NaN
# 463          NaN               NaN                  NaN
# 470          NaN               NaN                  NaN

# %% [markdown]
# Finally we export the datasets as csv files

# %%
df.to_csv("ksi_kk.csv",encoding='utf-8-sig', index = False)

# %%
df_kvk = pd.DataFrame(get_historic_data('f'))
df_kvk.to_csv('ksi_kvk.csv', encoding='utf-8-sig', index = False)
# Out:
# 2021
